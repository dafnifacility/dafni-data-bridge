# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# curl --location --request POST 'https://services.ceda.ac.uk/api/token/create/' --header "Authorization: Basic $(echo -n "...:..." | base64)"

# %%
import getpass
import json
import requests

from base64 import b64encode

# %%
CEDA_USERNAME = input("Enter DAFNI username: ")
CEDA_PASSWORD = getpass.getpass("Enter DAFNI password: ")

if not CEDA_USERNAME or not CEDA_PASSWORD:
    raise ValueError("CEDA_USERNAME and/or CEDA_PASSWORD were not provided.")

# %%
url = "https://services.ceda.ac.uk/api/token/create/"

username = CEDA_USERNAME
password = CEDA_PASSWORD
token = b64encode(f"{username}:{password}".encode('utf-8')).decode("ascii")
headers = {
    "Authorization": f'Basic {token}',
}

response = requests.request("POST", url, headers=headers)

# If successful, this will return a JSON response containing the token
response_data = json.loads(response.text)
print(response.text)
if response.status_code == 200:
    token = response_data["access_token"]
# Out:
# {"access_token":"eyJhbGciOiJSUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICI4ZjhmaUpyaUtDY3hmaHhzdU5vazVEekdJdFZ4amhhTWNJa05ZX2U4MnhJIn0.....PqFGuWjdarkiNf8MBY7AmOBbd6nulWs4rlOgaSAZCqrXDxQhKYtv-TWS_RwkoDaH0GMmKT5WkbSM9WbIQFJ5sHiqkWkcQkcipm86brbv9M-6l98tLBGVtUOUrUtF2twUQRwkTmIF3C6qODOPVryBbAEABy4BOOA3XpBNJOnjCmIyFui8ycUrm0zPARnBVu95rhcWvKwtq8y86umjh1D3BprN3VCkXQeDG9OFWuM7zSrQe21qGdjfs794raQT4OqKxu3ZJiYAv9sUSVwPPz77CsLN99jVZd4LtyHCGB42OLnaq_blzJIgSPkY7iHmtHJiugq8y9FuP8Vj43KMkjm-3A","expires":"2025-11-10T10:13:56.074806Z"}
